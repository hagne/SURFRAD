# %%
p = pl.Path('/Volumes/grad/Inst/MFR/SURFRAD/tbl/mfrsr/raw/')

# %%
p.exists()
# Out:
# True

# %%
p = pl.Path('/Volumes/grad/Inst/') / 'MFR/SURFRAD/tbl/mfrsr/raw/'

# %%
p.exists()
# Out:
# True

# %%
pl.Path.mkdir(

# %%
import surfradpy.radiation as srfrad

# %%
reload(srfrad)
# Out:
# <module 'surfradpy.radiation' from '/Users/htelg/prog/SURFRAD/surfradpy/radiation.py'>

# %%
out = srfrad.generate_netcdfs(
    p2fld='/Volumes/aftp/data/radiation/surfrad/',
    p2fldout='/Volumes/grad/surfrad/products_level1/radiation_netcdf/',
    gui=False,
    verbose=True,
    test=True,
)
# Out:
# output folder:/Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/dra
# p2flds: /Volumes/aftp/data/radiation/surfrad/dra
# years: [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026]

# %%
ds = out['ds_sample']

# %%
ds
# Out:
# <xarray.Dataset> Size: 78kB
# Dimensions:      (datetime: 441)
# Coordinates:
#   * datetime     (datetime) datetime64[ns] 4kB 1998-03-16T01:57:00 ... 1998-0...
# Data variables: (12/21)
#     zen          (datetime) float64 4kB 91.64 92.24 92.84 ... 66.71 67.27 67.83
#     dw_solar     (datetime) float64 4kB -3.0 -3.6 -4.0 -4.2 ... 82.4 74.8 76.2
#     uw_solar     (datetime) float64 4kB -1.1 -0.8 -0.9 -1.1 ... 17.9 15.6 16.0
#     direct_n     (datetime) float64 4kB -3.8 -3.6 -3.7 -3.8 ... -1.8 -5.9 -4.9
#     diffuse      (datetime) float64 4kB 3.1 2.6 2.1 2.0 ... 95.0 83.2 77.9 79.2
#     dw_ir        (datetime) float64 4kB 290.0 289.6 289.2 ... 356.9 357.2 357.8
#     ...           ...
#     totalnet     (datetime) float64 4kB -95.0 -95.0 -94.9 -94.5 ... 3.8 2.5 4.7
#     temp         (datetime) float64 4kB 18.8 18.6 18.5 18.3 ... 18.7 18.6 18.7
#     rh           (datetime) float64 4kB 31.9 32.1 32.4 33.3 ... 35.6 35.3 35.3
#     windspd      (datetime) float64 4kB 1.5 1.6 1.4 1.0 0.8 ... 2.9 2.7 2.6 2.0
#     winddir      (datetime) float64 4kB 227.6 232.5 236.4 ... 267.3 290.1 315.4
#     pressure     (datetime) float64 4kB 897.2 897.2 897.2 ... 894.4 894.5 894.6
