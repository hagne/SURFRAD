# %% [markdown]
# # Radflux database

# %%
import surfradpy.products.surfrad_radflux as srfrf

# %%
parent = srfrf.RadfluxClearskyParameterAnalysis.__mro__[1]
parent(

# %%
reload(srfrf.prowo)
reload(srfrf)
# Out:
# <module 'surfradpy.products.surfrad_radflux' from '/Users/htelg/prog/SURFRAD/surfradpy/products/surfrad_radflux.py'>

# %%
site = 'dra'
p2fld_in = f'/Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/{site}'
radflux_parameters_db = f'radflux_params_{site}.db'
path2raflux_setting = f'radflux_settings_{site}.toml'
self = srfrf.RadfluxClearskyParameterAnalysis(
    p2fld_in=p2fld_in,
    p2fld_out=None,
    database=None,
    file_name_format='*{date:%Y%m%d}*',
    output_file_format=None,
    start=None,
    end=None,
    days = 360,
    input_directory_structure='yearly',
    output_directory_structure=None,
    file_complete_check=False,
    reporter=None,
    verbose=True,
    radflux_parameters_db = radflux_parameters_db,
    path2raflux_setting = path2raflux_setting,
    site = site
)
# self.masterplan
self.workplan
# Out:
# start time: 2026-09-22 14:06:46.183271
# Get all files in /Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/dra with "files_between" function and start: 2025-09-27 14:06:46.183408, end: 2026-09-22 14:06:46.183442 and file_name_format: *{date:%Y%m%d}*
#                                                        p2f_in
# datetime
# 2026-09-21  /Volumes/grad/surfrad/products_level1/radiatio...

# %%
self.process(raise_errors=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  53
# Not enough clear sky points (53 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  71
# Not enough clear sky points (71 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  138
# New values
# normalized_total_shortwave_power_exponent: 1.2956830,
# normalized_total_shortwave_lower_limit_low_sun: 1018.79,
# normalized_total_shortwave_lower_limit_high_sun: 1018.8,
# normalized_total_shortwave_upper_limit: 1318.79,
# normalized_diffuse_ratio_power_exponent: -0.7518531
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  169
# New values
# normalized_total_shortwave_power_exponent: 1.3218713,
# normalized_total_shortwave_lower_limit_low_sun: 1038.18,
# normalized_total_shortwave_lower_limit_high_sun: 1038.2,
# normalized_total_shortwave_upper_limit: 1338.18,
# normalized_diffuse_ratio_power_exponent: -0.7485409
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  169
# New values
# normalized_total_shortwave_power_exponent: 1.3216181,
# normalized_total_shortwave_lower_limit_low_sun: 1037.60,
# normalized_total_shortwave_lower_limit_high_sun: 1037.6,
# normalized_total_shortwave_upper_limit: 1337.60,
# normalized_diffuse_ratio_power_exponent: -0.7481869
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  169
# New values
# normalized_total_shortwave_power_exponent: 1.3029641,
# normalized_total_shortwave_lower_limit_low_sun: 1070.15,
# normalized_total_shortwave_lower_limit_high_sun: 1070.1,
# normalized_total_shortwave_upper_limit: 1270.15,
# normalized_diffuse_ratio_power_exponent: -0.7400319
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.08456318790369298
# overwriting normalized_diffuse_ratio_power_exponent with -0.7400318991178298. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.740
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  413
# New values
# normalized_total_shortwave_power_exponent: 1.2593926,
# normalized_total_shortwave_lower_limit_low_sun: 1031.45,
# normalized_total_shortwave_lower_limit_high_sun: 1031.4,
# normalized_total_shortwave_upper_limit: 1331.45,
# normalized_diffuse_ratio_power_exponent: -0.8701384
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  467
# New values
# normalized_total_shortwave_power_exponent: 1.2762328,
# normalized_total_shortwave_lower_limit_low_sun: 1041.35,
# normalized_total_shortwave_lower_limit_high_sun: 1041.3,
# normalized_total_shortwave_upper_limit: 1341.35,
# normalized_diffuse_ratio_power_exponent: -0.8710909
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  469
# New values
# normalized_total_shortwave_power_exponent: 1.2771044,
# normalized_total_shortwave_lower_limit_low_sun: 1041.84,
# normalized_total_shortwave_lower_limit_high_sun: 1041.8,
# normalized_total_shortwave_upper_limit: 1341.84,
# normalized_diffuse_ratio_power_exponent: -0.8715269
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  470
# New values
# normalized_total_shortwave_power_exponent: 1.2489738,
# normalized_total_shortwave_lower_limit_low_sun: 1074.88,
# normalized_total_shortwave_lower_limit_high_sun: 1074.9,
# normalized_total_shortwave_upper_limit: 1274.88,
# normalized_diffuse_ratio_power_exponent: -0.8666657
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.06776933156021316
# overwriting normalized_diffuse_ratio_power_exponent with -0.8666656630098681. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1174.8812205455022
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2489738007505145. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.249,
# normalized_total_shortwave_lower_limit_low_sun: 1074.9,
# normalized_total_shortwave_lower_limit_high_sun: 1074.9,
# normalized_total_shortwave_upper_limit: 1274.9,
# normalized_diffuse_ratio_power_exponent: -0.867
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  590
# New values
# normalized_total_shortwave_power_exponent: 1.2597904,
# normalized_total_shortwave_lower_limit_low_sun: 1017.78,
# normalized_total_shortwave_lower_limit_high_sun: 1017.8,
# normalized_total_shortwave_upper_limit: 1317.78,
# normalized_diffuse_ratio_power_exponent: -0.8003953
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  627
# New values
# normalized_total_shortwave_power_exponent: 1.2844173,
# normalized_total_shortwave_lower_limit_low_sun: 1032.62,
# normalized_total_shortwave_lower_limit_high_sun: 1032.6,
# normalized_total_shortwave_upper_limit: 1332.62,
# normalized_diffuse_ratio_power_exponent: -0.8049374
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  626
# New values
# normalized_total_shortwave_power_exponent: 1.2838626,
# normalized_total_shortwave_lower_limit_low_sun: 1032.28,
# normalized_total_shortwave_lower_limit_high_sun: 1032.3,
# normalized_total_shortwave_upper_limit: 1332.28,
# normalized_diffuse_ratio_power_exponent: -0.8048027
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  626
# New values
# normalized_total_shortwave_power_exponent: 1.2486378,
# normalized_total_shortwave_lower_limit_low_sun: 1060.56,
# normalized_total_shortwave_lower_limit_high_sun: 1060.6,
# normalized_total_shortwave_upper_limit: 1260.56,
# normalized_diffuse_ratio_power_exponent: -0.8049710
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07578923379572723
# overwriting normalized_diffuse_ratio_power_exponent with -0.8049709766795832. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1160.5639416641027
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.248637825057167. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.249,
# normalized_total_shortwave_lower_limit_low_sun: 1060.6,
# normalized_total_shortwave_lower_limit_high_sun: 1060.6,
# normalized_total_shortwave_upper_limit: 1260.6,
# normalized_diffuse_ratio_power_exponent: -0.805
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  590
# New values
# normalized_total_shortwave_power_exponent: 1.2539072,
# normalized_total_shortwave_lower_limit_low_sun: 1015.52,
# normalized_total_shortwave_lower_limit_high_sun: 1015.5,
# normalized_total_shortwave_upper_limit: 1315.52,
# normalized_diffuse_ratio_power_exponent: -0.7731370
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  595
# New values
# normalized_total_shortwave_power_exponent: 1.2593469,
# normalized_total_shortwave_lower_limit_low_sun: 1018.58,
# normalized_total_shortwave_lower_limit_high_sun: 1018.6,
# normalized_total_shortwave_upper_limit: 1318.58,
# normalized_diffuse_ratio_power_exponent: -0.7698903
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  596
# New values
# normalized_total_shortwave_power_exponent: 1.2604123,
# normalized_total_shortwave_lower_limit_low_sun: 1019.19,
# normalized_total_shortwave_lower_limit_high_sun: 1019.2,
# normalized_total_shortwave_upper_limit: 1319.19,
# normalized_diffuse_ratio_power_exponent: -0.7692474
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  596
# New values
# normalized_total_shortwave_power_exponent: 1.2236767,
# normalized_total_shortwave_lower_limit_low_sun: 1049.27,
# normalized_total_shortwave_lower_limit_high_sun: 1049.3,
# normalized_total_shortwave_upper_limit: 1249.27,
# normalized_diffuse_ratio_power_exponent: -0.7659864
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07371824952571474
# overwriting normalized_diffuse_ratio_power_exponent with -0.7659864454299757. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1149.2674316713517
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2236767481422068. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.224,
# normalized_total_shortwave_lower_limit_low_sun: 1049.3,
# normalized_total_shortwave_lower_limit_high_sun: 1049.3,
# normalized_total_shortwave_upper_limit: 1249.3,
# normalized_diffuse_ratio_power_exponent: -0.766
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  251
# New values
# normalized_total_shortwave_power_exponent: 1.2648277,
# normalized_total_shortwave_lower_limit_low_sun: 1051.85,
# normalized_total_shortwave_lower_limit_high_sun: 1051.8,
# normalized_total_shortwave_upper_limit: 1351.85,
# normalized_diffuse_ratio_power_exponent: -0.7972854
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  288
# New values
# normalized_total_shortwave_power_exponent: 1.3049407,
# normalized_total_shortwave_lower_limit_low_sun: 1076.55,
# normalized_total_shortwave_lower_limit_high_sun: 1076.5,
# normalized_total_shortwave_upper_limit: 1376.55,
# normalized_diffuse_ratio_power_exponent: -0.8186524
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  292
# New values
# normalized_total_shortwave_power_exponent: 1.2971817,
# normalized_total_shortwave_lower_limit_low_sun: 1072.14,
# normalized_total_shortwave_lower_limit_high_sun: 1072.1,
# normalized_total_shortwave_upper_limit: 1372.14,
# normalized_diffuse_ratio_power_exponent: -0.8199616
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  292
# New values
# normalized_total_shortwave_power_exponent: 1.2523863,
# normalized_total_shortwave_lower_limit_low_sun: 1093.76,
# normalized_total_shortwave_lower_limit_high_sun: 1093.8,
# normalized_total_shortwave_upper_limit: 1293.76,
# normalized_diffuse_ratio_power_exponent: -0.8292882
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.06809785467589871
# overwriting normalized_diffuse_ratio_power_exponent with -0.8292882210535946. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1193.7593848514834
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2523862764215115. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.252,
# normalized_total_shortwave_lower_limit_low_sun: 1093.8,
# normalized_total_shortwave_lower_limit_high_sun: 1093.8,
# normalized_total_shortwave_upper_limit: 1293.8,
# normalized_diffuse_ratio_power_exponent: -0.829
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  235
# New values
# normalized_total_shortwave_power_exponent: 1.2829349,
# normalized_total_shortwave_lower_limit_low_sun: 1057.65,
# normalized_total_shortwave_lower_limit_high_sun: 1057.7,
# normalized_total_shortwave_upper_limit: 1357.65,
# normalized_diffuse_ratio_power_exponent: -0.8230732
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  272
# New values
# normalized_total_shortwave_power_exponent: 1.3153636,
# normalized_total_shortwave_lower_limit_low_sun: 1081.62,
# normalized_total_shortwave_lower_limit_high_sun: 1081.6,
# normalized_total_shortwave_upper_limit: 1381.62,
# normalized_diffuse_ratio_power_exponent: -0.8410056
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  268
# New values
# normalized_total_shortwave_power_exponent: 1.3131463,
# normalized_total_shortwave_lower_limit_low_sun: 1079.54,
# normalized_total_shortwave_lower_limit_high_sun: 1079.5,
# normalized_total_shortwave_upper_limit: 1379.54,
# normalized_diffuse_ratio_power_exponent: -0.8419633
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  268
# New values
# normalized_total_shortwave_power_exponent: 1.2770709,
# normalized_total_shortwave_lower_limit_low_sun: 1101.51,
# normalized_total_shortwave_lower_limit_high_sun: 1101.5,
# normalized_total_shortwave_upper_limit: 1301.51,
# normalized_diffuse_ratio_power_exponent: -0.8556478
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# ...
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07945975674226304
# overwriting normalized_diffuse_ratio_power_exponent with -0.8257991244394537. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1129.5069041243594
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2167896633827624. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.217,
# normalized_total_shortwave_lower_limit_low_sun: 1029.5,
# normalized_total_shortwave_lower_limit_high_sun: 1029.5,
# normalized_total_shortwave_upper_limit: 1229.5,
# normalized_diffuse_ratio_power_exponent: -0.826
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  491
# New values
# normalized_total_shortwave_power_exponent: 1.2565804,
# normalized_total_shortwave_lower_limit_low_sun: 1032.73,
# normalized_total_shortwave_lower_limit_high_sun: 1032.7,
# normalized_total_shortwave_upper_limit: 1332.73,
# normalized_diffuse_ratio_power_exponent: -0.8433806
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  522
# New values
# normalized_total_shortwave_power_exponent: 1.2760545,
# normalized_total_shortwave_lower_limit_low_sun: 1043.50,
# normalized_total_shortwave_lower_limit_high_sun: 1043.5,
# normalized_total_shortwave_upper_limit: 1343.50,
# normalized_diffuse_ratio_power_exponent: -0.8504136
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  531
# New values
# normalized_total_shortwave_power_exponent: 1.2831461,
# normalized_total_shortwave_lower_limit_low_sun: 1047.70,
# normalized_total_shortwave_lower_limit_high_sun: 1047.7,
# normalized_total_shortwave_upper_limit: 1347.70,
# normalized_diffuse_ratio_power_exponent: -0.8496307
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  534
# New values
# normalized_total_shortwave_power_exponent: 1.2502815,
# normalized_total_shortwave_lower_limit_low_sun: 1077.81,
# normalized_total_shortwave_lower_limit_high_sun: 1077.8,
# normalized_total_shortwave_upper_limit: 1277.81,
# normalized_diffuse_ratio_power_exponent: -0.8454033
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.06884504142680925
# overwriting normalized_diffuse_ratio_power_exponent with -0.8454032652058333. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1177.8106866093665
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2502814629462848. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.250,
# normalized_total_shortwave_lower_limit_low_sun: 1077.8,
# normalized_total_shortwave_lower_limit_high_sun: 1077.8,
# normalized_total_shortwave_upper_limit: 1277.8,
# normalized_diffuse_ratio_power_exponent: -0.845
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  646
# New values
# normalized_total_shortwave_power_exponent: 1.2405556,
# normalized_total_shortwave_lower_limit_low_sun: 1019.17,
# normalized_total_shortwave_lower_limit_high_sun: 1019.2,
# normalized_total_shortwave_upper_limit: 1319.17,
# normalized_diffuse_ratio_power_exponent: -0.7815131
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  660
# New values
# normalized_total_shortwave_power_exponent: 1.2506557,
# normalized_total_shortwave_lower_limit_low_sun: 1024.42,
# normalized_total_shortwave_lower_limit_high_sun: 1024.4,
# normalized_total_shortwave_upper_limit: 1324.42,
# normalized_diffuse_ratio_power_exponent: -0.7904648
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  667
# New values
# normalized_total_shortwave_power_exponent: 1.2557092,
# normalized_total_shortwave_lower_limit_low_sun: 1027.16,
# normalized_total_shortwave_lower_limit_high_sun: 1027.2,
# normalized_total_shortwave_upper_limit: 1327.16,
# normalized_diffuse_ratio_power_exponent: -0.7921646
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  669
# New values
# normalized_total_shortwave_power_exponent: 1.2127165,
# normalized_total_shortwave_lower_limit_low_sun: 1054.64,
# normalized_total_shortwave_lower_limit_high_sun: 1054.6,
# normalized_total_shortwave_upper_limit: 1254.64,
# normalized_diffuse_ratio_power_exponent: -0.7987277
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07492080012551497
# overwriting normalized_diffuse_ratio_power_exponent with -0.7987277499844014. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1154.6415322701973
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2127164673306832. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.213,
# normalized_total_shortwave_lower_limit_low_sun: 1054.6,
# normalized_total_shortwave_lower_limit_high_sun: 1054.6,
# normalized_total_shortwave_upper_limit: 1254.6,
# normalized_diffuse_ratio_power_exponent: -0.799
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  10
# Not enough clear sky points (10 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .We have to wait for the next day to to finish this local day.
# .

# %% [markdown]
# ## For testing

# %%
# i = 0
i += 1
out = self.process_row(iloc = i, 
                         save = False, 
                         # test = True,
                        )

ds = out['ds_wholeday']

# ds.global_horizontal.plot()

bbi = out['bbi']

bbi.plot_overview(show_clearsky=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  244
# New values
# normalized_total_shortwave_power_exponent: 1.2479359,
# normalized_total_shortwave_lower_limit_low_sun: 1024.23,
# normalized_total_shortwave_lower_limit_high_sun: 1024.2,
# normalized_total_shortwave_upper_limit: 1324.23,
# normalized_diffuse_ratio_power_exponent: -0.7559991
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2182799,
# normalized_total_shortwave_lower_limit_low_sun: 1052.32,
# normalized_total_shortwave_lower_limit_high_sun: 1052.3,
# normalized_total_shortwave_upper_limit: 1252.32,
# normalized_diffuse_ratio_power_exponent: -0.7793289
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='datetime', ylabel='Clear sky diffuse horizontal\nirradiance (empirical power\nlaw fit) [W m-2]'>)

# %% [markdown]
# # parameter check

# %%
import atmPy.radiation.radflux.radflux_db as atmrfdb

# %%
db12 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_12.db')
db = db12
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df12 = df

# %%
# db10 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_10.db')
# db = db10
# df = db.dump_radflux_parameters()
# df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
# df10 = df

db08 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_08.db')
db = db08
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df08 = df

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['12','08'
       # '20', '19', '18', '17', '15'
      ]
dfs = [df12, df08
       # df20, df19, df18, df17, df15
      ]
for i, df in enumerate(dfs):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
df = df12
nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()

ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()

f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 2)

sers = [nts_a, nts_b,ndr_a,ndr_b]

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]
for e,a in enumerate(aa):
    sers[e].plot(ax = a, ls = '', marker = '.')
    a.text(posn[0], posn[1], names[e], transform = a.transAxes)
    a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    # '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    # df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['25',
    '20', 
       # '19',
    # '18', 
    # '17', '15'
]
for i, df in enumerate([
    df25, 
    df20, 
    # df19, 
    # df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()
