# %% [markdown]
# # Radflux database

# %%
import surfradpy.products.surfrad_radflux as srfrf

# %%
parent = srfrf.RadfluxClearskyParameterAnalysis.__mro__[1]
# parent(

# %%
reload(srfrf.prowo)
reload(srfrf)
# Out:
# <module 'surfradpy.products.surfrad_radflux' from '/Users/htelg/prog/SURFRAD/surfradpy/products/surfrad_radflux.py'>

# %%
site = 'fpk'
p2fld_in = f'/Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/{site}'
radflux_parameters_db = f'radflux_params_{site}.db'
path2raflux_setting = f'radflux_settings_{site}.toml'
self = srfrf.RadfluxClearskyParameterAnalysis(
    p2fld_in=p2fld_in,
    p2fld_out=None,
    database=None,
    file_name_format='*{date:%Y%m%d}*',
    output_file_format=None,
    start=None,
    end=None,
    days = 360,
    input_directory_structure='yearly',
    output_directory_structure=None,
    file_complete_check=False,
    reporter=None,
    verbose=True,
    radflux_parameters_db = radflux_parameters_db,
    path2raflux_setting = path2raflux_setting,
    site = site
)
# self.masterplan
self.workplan
# Out:
# start time: 2026-09-22 14:14:09.474187
# Get all files in /Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/fpk with "files_between" function and start: 2025-09-27 14:14:09.474437, end: 2026-09-22 14:14:09.474567 and file_name_format: *{date:%Y%m%d}*
# Warning: Database radflux_params_fpk.db table radflux_parameters is empty.
#                                                        p2f_in
# datetime
# 2025-09-27  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-09-28  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-09-29  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-09-30  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-10-01  /Volumes/grad/surfrad/products_level1/radiatio...
# ...                                                       ...
# 2026-09-17  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-18  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-19  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-20  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-21  /Volumes/grad/surfrad/products_level1/radiatio...
#
# [360 rows x 1 columns]

# %%
self.process(raise_errors=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  323
# New values
# normalized_total_shortwave_power_exponent: 1.2622255,
# normalized_total_shortwave_lower_limit_low_sun: 1006.12,
# normalized_total_shortwave_lower_limit_high_sun: 1006.1,
# normalized_total_shortwave_upper_limit: 1306.12,
# normalized_diffuse_ratio_power_exponent: -0.8813885
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  365
# New values
# normalized_total_shortwave_power_exponent: 1.3078247,
# normalized_total_shortwave_lower_limit_low_sun: 1034.81,
# normalized_total_shortwave_lower_limit_high_sun: 1034.8,
# normalized_total_shortwave_upper_limit: 1334.81,
# normalized_diffuse_ratio_power_exponent: -1.1282451
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  399
# New values
# normalized_total_shortwave_power_exponent: 1.3203165,
# normalized_total_shortwave_lower_limit_low_sun: 1042.51,
# normalized_total_shortwave_lower_limit_high_sun: 1042.5,
# normalized_total_shortwave_upper_limit: 1342.51,
# normalized_diffuse_ratio_power_exponent: -1.0683740
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  397
# New values
# normalized_total_shortwave_power_exponent: 1.3163410,
# normalized_total_shortwave_lower_limit_low_sun: 1088.59,
# normalized_total_shortwave_lower_limit_high_sun: 1088.6,
# normalized_total_shortwave_upper_limit: 1288.59,
# normalized_diffuse_ratio_power_exponent: -0.7746786
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1188.5885588826836
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7746786374978353. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.0951333325980886
# overwriting normalized_total_shortwave_power_exponent with 1.3163410272422467. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.316,
# normalized_total_shortwave_lower_limit_low_sun: 1088.6,
# normalized_total_shortwave_lower_limit_high_sun: 1088.6,
# normalized_total_shortwave_upper_limit: 1288.6,
# normalized_diffuse_ratio_power_exponent: -0.775
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  327
# New values
# normalized_total_shortwave_power_exponent: 1.3137726,
# normalized_total_shortwave_lower_limit_low_sun: 1036.67,
# normalized_total_shortwave_lower_limit_high_sun: 1036.7,
# normalized_total_shortwave_upper_limit: 1336.67,
# normalized_diffuse_ratio_power_exponent: -0.6518167
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  340
# New values
# normalized_total_shortwave_power_exponent: 1.3074557,
# normalized_total_shortwave_lower_limit_low_sun: 1031.16,
# normalized_total_shortwave_lower_limit_high_sun: 1031.2,
# normalized_total_shortwave_upper_limit: 1331.16,
# normalized_diffuse_ratio_power_exponent: -0.6690189
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  339
# New values
# normalized_total_shortwave_power_exponent: 1.3077756,
# normalized_total_shortwave_lower_limit_low_sun: 1031.46,
# normalized_total_shortwave_lower_limit_high_sun: 1031.5,
# normalized_total_shortwave_upper_limit: 1331.46,
# normalized_diffuse_ratio_power_exponent: -0.6657280
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  340
# New values
# normalized_total_shortwave_power_exponent: 1.3068890,
# normalized_total_shortwave_lower_limit_low_sun: 1080.64,
# normalized_total_shortwave_lower_limit_high_sun: 1080.6,
# normalized_total_shortwave_upper_limit: 1280.64,
# normalized_diffuse_ratio_power_exponent: -0.6766939
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1180.6411811125474
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.6766939338412652. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.10742410476657993
# overwriting normalized_total_shortwave_power_exponent with 1.3068890353830986. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.307,
# normalized_total_shortwave_lower_limit_low_sun: 1080.6,
# normalized_total_shortwave_lower_limit_high_sun: 1080.6,
# normalized_total_shortwave_upper_limit: 1280.6,
# normalized_diffuse_ratio_power_exponent: -0.677
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  529
# New values
# normalized_total_shortwave_power_exponent: 1.3024785,
# normalized_total_shortwave_lower_limit_low_sun: 1004.07,
# normalized_total_shortwave_lower_limit_high_sun: 1004.1,
# normalized_total_shortwave_upper_limit: 1304.07,
# normalized_diffuse_ratio_power_exponent: -0.8518129
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  583
# New values
# normalized_total_shortwave_power_exponent: 1.3240019,
# normalized_total_shortwave_lower_limit_low_sun: 1019.77,
# normalized_total_shortwave_lower_limit_high_sun: 1019.8,
# normalized_total_shortwave_upper_limit: 1319.77,
# normalized_diffuse_ratio_power_exponent: -0.8650063
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  581
# New values
# normalized_total_shortwave_power_exponent: 1.3223641,
# normalized_total_shortwave_lower_limit_low_sun: 1018.65,
# normalized_total_shortwave_lower_limit_high_sun: 1018.6,
# normalized_total_shortwave_upper_limit: 1318.65,
# normalized_diffuse_ratio_power_exponent: -0.8651430
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  580
# New values
# normalized_total_shortwave_power_exponent: 1.2941469,
# normalized_total_shortwave_lower_limit_low_sun: 1047.53,
# normalized_total_shortwave_lower_limit_high_sun: 1047.5,
# normalized_total_shortwave_upper_limit: 1247.53,
# normalized_diffuse_ratio_power_exponent: -0.8385971
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1147.532505067463
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.8385971148239733. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.10530076078660261
# overwriting normalized_total_shortwave_power_exponent with 1.2941469180191911. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.294,
# normalized_total_shortwave_lower_limit_low_sun: 1047.5,
# normalized_total_shortwave_lower_limit_high_sun: 1047.5,
# normalized_total_shortwave_upper_limit: 1247.5,
# normalized_diffuse_ratio_power_exponent: -0.839
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  385
# New values
# normalized_total_shortwave_power_exponent: 1.3079464,
# normalized_total_shortwave_lower_limit_low_sun: 1021.16,
# normalized_total_shortwave_lower_limit_high_sun: 1021.2,
# normalized_total_shortwave_upper_limit: 1321.16,
# normalized_diffuse_ratio_power_exponent: -1.0166988
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  400
# New values
# normalized_total_shortwave_power_exponent: 1.3439643,
# normalized_total_shortwave_lower_limit_low_sun: 1045.43,
# normalized_total_shortwave_lower_limit_high_sun: 1045.4,
# normalized_total_shortwave_upper_limit: 1345.43,
# normalized_diffuse_ratio_power_exponent: -1.0088239
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  401
# New values
# normalized_total_shortwave_power_exponent: 1.3500660,
# normalized_total_shortwave_lower_limit_low_sun: 1049.55,
# normalized_total_shortwave_lower_limit_high_sun: 1049.5,
# normalized_total_shortwave_upper_limit: 1349.55,
# normalized_diffuse_ratio_power_exponent: -1.0057498
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  401
# New values
# normalized_total_shortwave_power_exponent: 1.2906282,
# normalized_total_shortwave_lower_limit_low_sun: 1059.10,
# normalized_total_shortwave_lower_limit_high_sun: 1059.1,
# normalized_total_shortwave_upper_limit: 1259.10,
# normalized_diffuse_ratio_power_exponent: -0.9898053
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: True, interpolate b.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1159.0975561164696
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.8385971148239733. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07170303918569951
# overwriting normalized_total_shortwave_power_exponent with 1.2906281971030529. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.291,
# normalized_total_shortwave_lower_limit_low_sun: 1059.1,
# normalized_total_shortwave_lower_limit_high_sun: 1059.1,
# normalized_total_shortwave_upper_limit: 1259.1,
# normalized_diffuse_ratio_power_exponent: -0.839
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  136
# New values
# normalized_total_shortwave_power_exponent: 1.2612662,
# normalized_total_shortwave_lower_limit_low_sun: 1010.53,
# normalized_total_shortwave_lower_limit_high_sun: 1010.5,
# normalized_total_shortwave_upper_limit: 1310.53,
# normalized_diffuse_ratio_power_exponent: -0.7648424
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  150
# New values
# normalized_total_shortwave_power_exponent: 1.2579349,
# normalized_total_shortwave_lower_limit_low_sun: 1010.17,
# normalized_total_shortwave_lower_limit_high_sun: 1010.2,
# normalized_total_shortwave_upper_limit: 1310.17,
# normalized_diffuse_ratio_power_exponent: -0.7708820
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  150
# New values
# normalized_total_shortwave_power_exponent: 1.2579349,
# normalized_total_shortwave_lower_limit_low_sun: 1010.17,
# normalized_total_shortwave_lower_limit_high_sun: 1010.2,
# normalized_total_shortwave_upper_limit: 1310.17,
# normalized_diffuse_ratio_power_exponent: -0.7708820
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  150
# New values
# normalized_total_shortwave_power_exponent: 1.1720197,
# normalized_total_shortwave_lower_limit_low_sun: 1005.47,
# normalized_total_shortwave_lower_limit_high_sun: 1005.5,
# normalized_total_shortwave_upper_limit: 1205.47,
# normalized_diffuse_ratio_power_exponent: -0.7519421
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1105.4715164726863
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7519420905131768. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.08177603694891049
# overwriting normalized_total_shortwave_power_exponent with 1.1720196873877704. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.172,
# normalized_total_shortwave_lower_limit_low_sun: 1005.5,
# normalized_total_shortwave_lower_limit_high_sun: 1005.5,
# normalized_total_shortwave_upper_limit: 1205.5,
# normalized_diffuse_ratio_power_exponent: -0.752
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  15
# Not enough clear sky points (15 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1105.4715164726863
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7519420905131768. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.08177603694891049
# overwriting normalized_total_shortwave_power_exponent with 1.1720196873877704. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.172,
# normalized_total_shortwave_lower_limit_low_sun: 1005.5,
# normalized_total_shortwave_lower_limit_high_sun: 1005.5,
# normalized_total_shortwave_upper_limit: 1205.5,
# normalized_diffuse_ratio_power_exponent: -0.752
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1105.4715164726863
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7519420905131768. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.08177603694891049
# overwriting normalized_total_shortwave_power_exponent with 1.1720196873877704. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.172,
# normalized_total_shortwave_lower_limit_low_sun: 1005.5,
# normalized_total_shortwave_lower_limit_high_sun: 1005.5,
# normalized_total_shortwave_upper_limit: 1205.5,
# normalized_diffuse_ratio_power_exponent: -0.752
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1105.4715164726863
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7519420905131768. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.08177603694891049
# overwriting normalized_total_shortwave_power_exponent with 1.1720196873877704. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.172,
# normalized_total_shortwave_lower_limit_low_sun: 1005.5,
# normalized_total_shortwave_lower_limit_high_sun: 1005.5,
# normalized_total_shortwave_upper_limit: 1205.5,
# normalized_diffuse_ratio_power_exponent: -0.752
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  37
# ...
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  275
# New values
# normalized_total_shortwave_power_exponent: 1.2727714,
# normalized_total_shortwave_lower_limit_low_sun: 990.70,
# normalized_total_shortwave_lower_limit_high_sun: 990.7,
# normalized_total_shortwave_upper_limit: 1290.70,
# normalized_diffuse_ratio_power_exponent: -0.6355765
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  275
# New values
# normalized_total_shortwave_power_exponent: 1.2312468,
# normalized_total_shortwave_lower_limit_low_sun: 1011.64,
# normalized_total_shortwave_lower_limit_high_sun: 1011.6,
# normalized_total_shortwave_upper_limit: 1211.64,
# normalized_diffuse_ratio_power_exponent: -0.6421295
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1111.6352957113888
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.6421295381739741. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.10424843565371021
# overwriting normalized_total_shortwave_power_exponent with 1.231246783723596. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.231,
# normalized_total_shortwave_lower_limit_low_sun: 1011.6,
# normalized_total_shortwave_lower_limit_high_sun: 1011.6,
# normalized_total_shortwave_upper_limit: 1211.6,
# normalized_diffuse_ratio_power_exponent: -0.642
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1111.6352957113888
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.6421295381739741. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.10424843565371021
# overwriting normalized_total_shortwave_power_exponent with 1.231246783723596. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.231,
# normalized_total_shortwave_lower_limit_low_sun: 1011.6,
# normalized_total_shortwave_lower_limit_high_sun: 1011.6,
# normalized_total_shortwave_upper_limit: 1211.6,
# normalized_diffuse_ratio_power_exponent: -0.642
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  81
# Not enough clear sky points (81 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1111.6352957113888
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.6421295381739741. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.10424843565371021
# overwriting normalized_total_shortwave_power_exponent with 1.231246783723596. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.231,
# normalized_total_shortwave_lower_limit_low_sun: 1011.6,
# normalized_total_shortwave_lower_limit_high_sun: 1011.6,
# normalized_total_shortwave_upper_limit: 1211.6,
# normalized_diffuse_ratio_power_exponent: -0.642
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0015
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_total_shortwave_power_coefficient to 1111.6352957113888
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.6421295381739741. (old value: -0.8)
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.10424843565371021
# overwriting normalized_total_shortwave_power_exponent with 1.231246783723596. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.231,
# normalized_total_shortwave_lower_limit_low_sun: 1011.6,
# normalized_total_shortwave_lower_limit_high_sun: 1011.6,
# normalized_total_shortwave_upper_limit: 1211.6,
# normalized_diffuse_ratio_power_exponent: -0.642
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .We have to wait for the next day to to finish this local day.
# .

# %% [markdown]
# ## For testing

# %%
# i = 0
i += 1
out = self.process_row(iloc = i, 
                         save = False, 
                         # test = True,
                        )

ds = out['ds_wholeday']

# ds.global_horizontal.plot()

bbi = out['bbi']

bbi.plot_overview(show_clearsky=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  244
# New values
# normalized_total_shortwave_power_exponent: 1.2479359,
# normalized_total_shortwave_lower_limit_low_sun: 1024.23,
# normalized_total_shortwave_lower_limit_high_sun: 1024.2,
# normalized_total_shortwave_upper_limit: 1324.23,
# normalized_diffuse_ratio_power_exponent: -0.7559991
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2182799,
# normalized_total_shortwave_lower_limit_low_sun: 1052.32,
# normalized_total_shortwave_lower_limit_high_sun: 1052.3,
# normalized_total_shortwave_upper_limit: 1252.32,
# normalized_diffuse_ratio_power_exponent: -0.7793289
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='datetime', ylabel='Clear sky diffuse horizontal\nirradiance (empirical power\nlaw fit) [W m-2]'>)

# %% [markdown]
# # parameter check

# %%
import atmPy.radiation.radflux.radflux_db as atmrfdb

# %%
plt.rcParams['figure.dpi'] = 200

# %%
db12 = atmrfdb.RadfluxParameterDatabase(f'databases/radflux_params_{site}_12.db')
db = db12
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df12 = df

# %%
db15 = atmrfdb.RadfluxParameterDatabase(f'databases/radflux_params_{site}_15.db')
db = db15
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df15 = df

# db10 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_10.db')
# db = db10
# df = db.dump_radflux_parameters()
# df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
# df10 = df

# db08 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_08.db')
# db = db08
# df = db.dump_radflux_parameters()
# df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
# df08 = df

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['12','15',
      ]
dfs = [df12, df15,
      ]
for i, df in enumerate(dfs):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
df = df12
nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()

ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()

f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 2)

sers = [nts_a, nts_b,ndr_a,ndr_b]

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]
for e,a in enumerate(aa):
    sers[e].plot(ax = a, ls = '', marker = '.')
    a.text(posn[0], posn[1], names[e], transform = a.transAxes)
    a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    # '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    # df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['25',
    '20', 
       # '19',
    # '18', 
    # '17', '15'
]
for i, df in enumerate([
    df25, 
    df20, 
    # df19, 
    # df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()
