# %% [markdown]
# # Radflux database

# %%
import surfradpy.products.surfrad_radflux as srfrf

# %%
parent = srfrf.RadfluxClearskyParameterAnalysis.__mro__[1]
# parent(

# %%
reload(srfrf.prowo)
reload(srfrf)
# Out:
# <module 'surfradpy.products.surfrad_radflux' from '/Users/htelg/prog/SURFRAD/surfradpy/products/surfrad_radflux.py'>

# %%
site = 'psu'
p2fld_in = f'/Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/{site}'
radflux_parameters_db = f'radflux_params_{site}.db'
path2raflux_setting = f'radflux_settings_{site}.toml'
self = srfrf.RadfluxClearskyParameterAnalysis(
    p2fld_in=p2fld_in,
    p2fld_out=None,
    database=None,
    file_name_format='*{date:%Y%m%d}*',
    output_file_format=None,
    start=None,
    end=None,
    days = 360,
    input_directory_structure='yearly',
    output_directory_structure=None,
    file_complete_check=False,
    reporter=None,
    verbose=True,
    radflux_parameters_db = radflux_parameters_db,
    path2raflux_setting = path2raflux_setting,
    site = site
)
# self.masterplan
self.workplan
# Out:
# start time: 2026-09-22 14:38:44.303670
# Get all files in /Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/psu with "files_between" function and start: 2025-09-27 14:38:44.303810, end: 2026-09-22 14:38:44.303846 and file_name_format: *{date:%Y%m%d}*
# Warning: Database radflux_params_psu.db table radflux_parameters is empty.
#                                                        p2f_in
# datetime
# 2025-09-27  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-09-28  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-09-29  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-09-30  /Volumes/grad/surfrad/products_level1/radiatio...
# 2025-10-01  /Volumes/grad/surfrad/products_level1/radiatio...
# ...                                                       ...
# 2026-09-17  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-18  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-19  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-20  /Volumes/grad/surfrad/products_level1/radiatio...
# 2026-09-21  /Volumes/grad/surfrad/products_level1/radiatio...
#
# [352 rows x 1 columns]

# %%
self.process(raise_errors=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  210
# New values
# normalized_total_shortwave_power_exponent: 1.2275910,
# normalized_total_shortwave_lower_limit_low_sun: 953.40,
# normalized_total_shortwave_lower_limit_high_sun: 953.4,
# normalized_total_shortwave_upper_limit: 1253.40,
# normalized_diffuse_ratio_power_exponent: -0.8788277
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  231
# New values
# normalized_total_shortwave_power_exponent: 1.2944682,
# normalized_total_shortwave_lower_limit_low_sun: 983.08,
# normalized_total_shortwave_lower_limit_high_sun: 983.1,
# normalized_total_shortwave_upper_limit: 1283.08,
# normalized_diffuse_ratio_power_exponent: -0.8094998
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  239
# New values
# normalized_total_shortwave_power_exponent: 1.3305656,
# normalized_total_shortwave_lower_limit_low_sun: 1000.46,
# normalized_total_shortwave_lower_limit_high_sun: 1000.5,
# normalized_total_shortwave_upper_limit: 1300.46,
# normalized_diffuse_ratio_power_exponent: -0.7630745
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  236
# New values
# normalized_total_shortwave_power_exponent: 1.2723087,
# normalized_total_shortwave_lower_limit_low_sun: 1022.76,
# normalized_total_shortwave_lower_limit_high_sun: 1022.8,
# normalized_total_shortwave_upper_limit: 1222.76,
# normalized_diffuse_ratio_power_exponent: -0.7295303
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.11602036450007802
# overwriting normalized_total_shortwave_power_exponent with 1.2723087483448705. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1122.755442725787
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7295302573210372. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.272,
# normalized_total_shortwave_lower_limit_low_sun: 1022.8,
# normalized_total_shortwave_lower_limit_high_sun: 1022.8,
# normalized_total_shortwave_upper_limit: 1222.8,
# normalized_diffuse_ratio_power_exponent: -0.730
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.11602036450007802
# overwriting normalized_total_shortwave_power_exponent with 1.2723087483448705. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1122.755442725787
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7295302573210372. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.272,
# normalized_total_shortwave_lower_limit_low_sun: 1022.8,
# normalized_total_shortwave_lower_limit_high_sun: 1022.8,
# normalized_total_shortwave_upper_limit: 1222.8,
# normalized_diffuse_ratio_power_exponent: -0.730
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  3
# Not enough clear sky points (3 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# /Users/htelg/miniconda3/envs/py13/lib/python3.13/site-packages/numbagg/decorators.py:331: RuntimeWarning: divide by zero encountered in move_mean
#   return gufunc(*arr, window, min_count, axis=axis, **kwargs)
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.11602036450007802
# overwriting normalized_total_shortwave_power_exponent with 1.2723087483448705. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1122.755442725787
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.7295302573210372. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.272,
# normalized_total_shortwave_lower_limit_low_sun: 1022.8,
# normalized_total_shortwave_lower_limit_high_sun: 1022.8,
# normalized_total_shortwave_upper_limit: 1222.8,
# normalized_diffuse_ratio_power_exponent: -0.730
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  485
# New values
# normalized_total_shortwave_power_exponent: 1.2797692,
# normalized_total_shortwave_lower_limit_low_sun: 1058.09,
# normalized_total_shortwave_lower_limit_high_sun: 1058.1,
# normalized_total_shortwave_upper_limit: 1358.09,
# normalized_diffuse_ratio_power_exponent: -0.8226605
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  584
# New values
# normalized_total_shortwave_power_exponent: 1.2794653,
# normalized_total_shortwave_lower_limit_low_sun: 1062.06,
# normalized_total_shortwave_lower_limit_high_sun: 1062.1,
# normalized_total_shortwave_upper_limit: 1362.06,
# normalized_diffuse_ratio_power_exponent: -0.8346868
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  584
# New values
# normalized_total_shortwave_power_exponent: 1.2794653,
# normalized_total_shortwave_lower_limit_low_sun: 1062.06,
# normalized_total_shortwave_lower_limit_high_sun: 1062.1,
# normalized_total_shortwave_upper_limit: 1362.06,
# normalized_diffuse_ratio_power_exponent: -0.8346868
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  584
# New values
# normalized_total_shortwave_power_exponent: 1.2651587,
# normalized_total_shortwave_lower_limit_low_sun: 1101.19,
# normalized_total_shortwave_lower_limit_high_sun: 1101.2,
# normalized_total_shortwave_upper_limit: 1301.19,
# normalized_diffuse_ratio_power_exponent: -0.8150441
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.0681320982275939
# overwriting normalized_total_shortwave_power_exponent with 1.2651587228696817. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1201.1940171066635
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.8150441081147715. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.265,
# normalized_total_shortwave_lower_limit_low_sun: 1101.2,
# normalized_total_shortwave_lower_limit_high_sun: 1101.2,
# normalized_total_shortwave_upper_limit: 1301.2,
# normalized_diffuse_ratio_power_exponent: -0.815
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  60
# Not enough clear sky points (60 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.0681320982275939
# overwriting normalized_total_shortwave_power_exponent with 1.2651587228696817. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1201.1940171066635
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.8150441081147715. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.265,
# normalized_total_shortwave_lower_limit_low_sun: 1101.2,
# normalized_total_shortwave_lower_limit_high_sun: 1101.2,
# normalized_total_shortwave_upper_limit: 1301.2,
# normalized_diffuse_ratio_power_exponent: -0.815
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  295
# New values
# normalized_total_shortwave_power_exponent: 1.2748253,
# normalized_total_shortwave_lower_limit_low_sun: 1011.73,
# normalized_total_shortwave_lower_limit_high_sun: 1011.7,
# normalized_total_shortwave_upper_limit: 1311.73,
# normalized_diffuse_ratio_power_exponent: -0.8443546
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  348
# New values
# normalized_total_shortwave_power_exponent: 1.3331684,
# normalized_total_shortwave_lower_limit_low_sun: 1042.57,
# normalized_total_shortwave_lower_limit_high_sun: 1042.6,
# normalized_total_shortwave_upper_limit: 1342.57,
# normalized_diffuse_ratio_power_exponent: -0.9162490
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  344
# New values
# normalized_total_shortwave_power_exponent: 1.3470174,
# normalized_total_shortwave_lower_limit_low_sun: 1050.58,
# normalized_total_shortwave_lower_limit_high_sun: 1050.6,
# normalized_total_shortwave_upper_limit: 1350.58,
# normalized_diffuse_ratio_power_exponent: -0.9262103
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  344
# New values
# normalized_total_shortwave_power_exponent: 1.3054776,
# normalized_total_shortwave_lower_limit_low_sun: 1076.74,
# normalized_total_shortwave_lower_limit_high_sun: 1076.7,
# normalized_total_shortwave_upper_limit: 1276.74,
# normalized_diffuse_ratio_power_exponent: -0.9500162
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: True, interpolate b.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07676769943290197
# overwriting normalized_total_shortwave_power_exponent with 1.305477635698533. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1176.740432913623
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.8150441081147715. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.305,
# normalized_total_shortwave_lower_limit_low_sun: 1076.7,
# normalized_total_shortwave_lower_limit_high_sun: 1076.7,
# normalized_total_shortwave_upper_limit: 1276.7,
# normalized_diffuse_ratio_power_exponent: -0.815
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  197
# New values
# normalized_total_shortwave_power_exponent: 1.2950885,
# normalized_total_shortwave_lower_limit_low_sun: 1025.74,
# normalized_total_shortwave_lower_limit_high_sun: 1025.7,
# normalized_total_shortwave_upper_limit: 1325.74,
# normalized_diffuse_ratio_power_exponent: -0.7943545
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  204
# New values
# normalized_total_shortwave_power_exponent: 1.2895696,
# normalized_total_shortwave_lower_limit_low_sun: 1021.57,
# normalized_total_shortwave_lower_limit_high_sun: 1021.6,
# normalized_total_shortwave_upper_limit: 1321.57,
# normalized_diffuse_ratio_power_exponent: -0.7724844
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  206
# New values
# normalized_total_shortwave_power_exponent: 1.2905007,
# normalized_total_shortwave_lower_limit_low_sun: 1022.04,
# normalized_total_shortwave_lower_limit_high_sun: 1022.0,
# normalized_total_shortwave_upper_limit: 1322.04,
# normalized_diffuse_ratio_power_exponent: -0.7738487
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  206
# New values
# normalized_total_shortwave_power_exponent: 1.2972012,
# normalized_total_shortwave_lower_limit_low_sun: 1076.76,
# normalized_total_shortwave_lower_limit_high_sun: 1076.8,
# normalized_total_shortwave_upper_limit: 1276.76,
# normalized_diffuse_ratio_power_exponent: -0.6898713
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.09438276262081835
# overwriting normalized_total_shortwave_power_exponent with 1.305477635698533. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1176.740432913623
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.6898713464286759. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.305,
# normalized_total_shortwave_lower_limit_low_sun: 1076.7,
# normalized_total_shortwave_lower_limit_high_sun: 1076.7,
# normalized_total_shortwave_upper_limit: 1276.7,
# normalized_diffuse_ratio_power_exponent: -0.690
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  529
# New values
# normalized_total_shortwave_power_exponent: 1.2929681,
# normalized_total_shortwave_lower_limit_low_sun: 1040.27,
# normalized_total_shortwave_lower_limit_high_sun: 1040.3,
# normalized_total_shortwave_upper_limit: 1340.27,
# normalized_diffuse_ratio_power_exponent: -0.8700638
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  542
# New values
# normalized_total_shortwave_power_exponent: 1.2970031,
# normalized_total_shortwave_lower_limit_low_sun: 1042.30,
# normalized_total_shortwave_lower_limit_high_sun: 1042.3,
# normalized_total_shortwave_upper_limit: 1342.30,
# normalized_diffuse_ratio_power_exponent: -0.9089621
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  543
# New values
# normalized_total_shortwave_power_exponent: 1.2990755,
# normalized_total_shortwave_lower_limit_low_sun: 1043.60,
# normalized_total_shortwave_lower_limit_high_sun: 1043.6,
# normalized_total_shortwave_upper_limit: 1343.60,
# normalized_diffuse_ratio_power_exponent: -0.9112547
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  545
# New values
# normalized_total_shortwave_power_exponent: 1.2853082,
# normalized_total_shortwave_lower_limit_low_sun: 1084.26,
# normalized_total_shortwave_lower_limit_high_sun: 1084.3,
# normalized_total_shortwave_upper_limit: 1284.26,
# normalized_diffuse_ratio_power_exponent: -0.8939408
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# ...
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.1436873735323623
# overwriting normalized_total_shortwave_power_exponent with 1.2170481936440558. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1045.6352658372289
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.5114140370454894. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.217,
# normalized_total_shortwave_lower_limit_low_sun: 945.6,
# normalized_total_shortwave_lower_limit_high_sun: 945.6,
# normalized_total_shortwave_upper_limit: 1145.6,
# normalized_diffuse_ratio_power_exponent: -0.511
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  5
# Not enough clear sky points (5 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.1436873735323623
# overwriting normalized_total_shortwave_power_exponent with 1.2170481936440558. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1045.6352658372289
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.5114140370454894. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.217,
# normalized_total_shortwave_lower_limit_low_sun: 945.6,
# normalized_total_shortwave_lower_limit_high_sun: 945.6,
# normalized_total_shortwave_upper_limit: 1145.6,
# normalized_diffuse_ratio_power_exponent: -0.511
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.1436873735323623
# overwriting normalized_total_shortwave_power_exponent with 1.2170481936440558. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1045.6352658372289
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.5114140370454894. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.217,
# normalized_total_shortwave_lower_limit_low_sun: 945.6,
# normalized_total_shortwave_lower_limit_high_sun: 945.6,
# normalized_total_shortwave_upper_limit: 1145.6,
# normalized_diffuse_ratio_power_exponent: -0.511
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.1436873735323623
# overwriting normalized_total_shortwave_power_exponent with 1.2170481936440558. (old value: 1.18)
# setting new variable normalized_total_shortwave_power_coefficient to 1045.6352658372289
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_diffuse_ratio_power_exponent with -0.5114140370454894. (old value: -0.8)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.217,
# normalized_total_shortwave_lower_limit_low_sun: 945.6,
# normalized_total_shortwave_lower_limit_high_sun: 945.6,
# normalized_total_shortwave_upper_limit: 1145.6,
# normalized_diffuse_ratio_power_exponent: -0.511
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# {'ds_wholeday': <xarray.Dataset> Size: 190kB
#  Dimensions:                                    (datetime: 729)
#  Coordinates:
#    * datetime                                   (datetime) datetime64[ns] 6kB ...
#  Data variables: (12/36)
#      zen                                        (datetime) float64 6kB 89.89 ....
#      global_horizontal                          (datetime) float64 6kB 7.3 ......
#      uw_solar                                   (datetime) float64 6kB 2.7 ......
#      direct_normal                              (datetime) float64 6kB -0.1 .....
#      diffuse_horizontal                         (datetime) float64 6kB 7.8 ......
#      dw_ir                                      (datetime) float64 6kB 360.7 ....
#      ...                                         ...
#      mu0                                        (datetime) float64 6kB 0.00026...
#      mask_normalized_global_magnitude           (datetime) bool 729B False ......
#      mask_diffuse_magnitude                     (datetime) bool 729B False ......
#      mask_global_irradiance_temporal_gradient   (datetime) bool 729B True ... ...
#      mask_normalized_diffuse_ratio_variability  (datetime) bool 729B False ......
#      mask_clear_sky_shortwave                   (datetime) bool 729B False ......
#  Attributes: (12/26)
#      parent_files:                                                  /nfs/iftp/...
#      processing_date:                                               2026-09-22...
#      processing_server:                                             pulsar5.cm...
#      processing_class:                                              This file ...
#      product_version:                                               1.1
#      maximum_solar_zenith_angle:                                    90.0
#      ...                                                            ...
#      normalized_total_shortwave_upper_limit:                        1145.63526...
#      normalized_diffuse_ratio_power_coefficient:                    0.14368737...
#      normalized_total_shortwave_power_exponent:                     1.21704819...
#      normalized_total_shortwave_power_coefficient:                  1045.63526...
#      normalized_diffuse_ratio_power_exponent:                       -0.5114140...
#      clear_sky_parameters_optimization_status:                      True,
#  'bbi': <atmPy.radiation.radflux.lab.RadFlux at 0x3078d91d0>,
#  'radflux_res': <xarray.Dataset> Size: 144B
#  Dimensions:                                                                ()
#  Data variables: (12/25)
#      n_clear                                                                int64 8B ...
#      clear_fraction                                                         int64 8B ...
#      n_clear_global_irradiance_termporal_gradiant                           int64 8B ...
#      n_clear_normalized_diffuse_ratio_variability                           int64 8B ...
#      n_clear_diffuse_magnitude                                              int64 8B ...
#      n_clear_normalized_global_magnitude                                    int64 8B ...
#      ...                                                                     ...
#      diffuse_ratio_cosine_coverage_sufficient                               bool 1B ...
#      normalized_total_shortwave_power_coefficient_is_valid                  bool 1B ...
#      normalized_total_shortwave_power_exponent_is_valid                     bool 1B ...
#      normalized_diffuse_ratio_power_coefficient_is_valid                    bool 1B ...
#      normalized_diffuse_ratio_power_exponent_is_valid                       bool 1B ...
#      n_clear_above_limit                                                    bool 1B ...
#  Attributes:
#      description:  Clear-sky parameter optimization results and diagnostics.
#      conclusion:   Fail, not enough clear sky points.}

# %% [markdown]
# ## For testing

# %%
# i = 0
i += 1
out = self.process_row(iloc = i, 
                         save = False, 
                         # test = True,
                        )

ds = out['ds_wholeday']

# ds.global_horizontal.plot()

bbi = out['bbi']

bbi.plot_overview(show_clearsky=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  244
# New values
# normalized_total_shortwave_power_exponent: 1.2479359,
# normalized_total_shortwave_lower_limit_low_sun: 1024.23,
# normalized_total_shortwave_lower_limit_high_sun: 1024.2,
# normalized_total_shortwave_upper_limit: 1324.23,
# normalized_diffuse_ratio_power_exponent: -0.7559991
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2182799,
# normalized_total_shortwave_lower_limit_low_sun: 1052.32,
# normalized_total_shortwave_lower_limit_high_sun: 1052.3,
# normalized_total_shortwave_upper_limit: 1252.32,
# normalized_diffuse_ratio_power_exponent: -0.7793289
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='datetime', ylabel='Clear sky diffuse horizontal\nirradiance (empirical power\nlaw fit) [W m-2]'>)

# %% [markdown]
# # parameter check

# %%
import atmPy.radiation.radflux.radflux_db as atmrfdb

# %%
db12 = atmrfdb.RadfluxParameterDatabase(f'databases/radflux_params_{site}_12.db')
db = db12
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df12 = df

# %%
db15 = atmrfdb.RadfluxParameterDatabase(f'databases/radflux_params_{site}_15.db')
db = db15
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df15 = df

# %%
# db10 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_10.db')
# db = db10
# df = db.dump_radflux_parameters()
# df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
# df10 = df

# db08 = atmrfdb.RadfluxParameterDatabase(f'radflux_params_{site}_08.db')
# db = db08
# df = db.dump_radflux_parameters()
# df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
# df08 = df

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['15','12'
      ]
dfs = [df15, df12
       # df20, df19, df18, df17, df15
      ]
for i, df in enumerate(dfs):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
df = df12
nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()

ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()

f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 2)

sers = [nts_a, nts_b,ndr_a,ndr_b]

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]
for e,a in enumerate(aa):
    sers[e].plot(ax = a, ls = '', marker = '.')
    a.text(posn[0], posn[1], names[e], transform = a.transAxes)
    a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = df12
#       2 nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
#       3 nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
#       4
#
# NameError: name 'df12' is not defined

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    # '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    # df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['25',
    '20', 
       # '19',
    # '18', 
    # '17', '15'
]
for i, df in enumerate([
    df25, 
    df20, 
    # df19, 
    # df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()
