# %% [markdown]
# # Radflux database

# %%
import surfradpy.products.surfrad_radflux as srfrf

# %%
parent = srfrf.RadfluxClearskyParameterAnalysis.__mro__[1]
parent(

# %%
reload(srfrf.prowo)
reload(srfrf)
# Out:
# <module 'surfradpy.products.surfrad_radflux' from '/Users/htelg/prog/SURFRAD/surfradpy/products/surfrad_radflux.py'>

# %%
site = 'tbl'
p2fld_in = f'/Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/{site}'
radflux_parameters_db = f'radflux_params_{site}.db'
path2raflux_setting = f'radflux_settings_{site}.toml'
self = srfrf.RadfluxClearskyParameterAnalysis(
    p2fld_in=p2fld_in,
    p2fld_out=None,
    database=None,
    file_name_format='*{date:%Y%m%d}*',
    output_file_format=None,
    start=None,
    end=None,
    days = 360,
    input_directory_structure='yearly',
    output_directory_structure=None,
    file_complete_check=False,
    reporter=None,
    verbose=True,
    radflux_parameters_db = radflux_parameters_db,
    path2raflux_setting = path2raflux_setting,
    site = site
)
# self.masterplan
self.workplan
# Out:
# start time: 2026-09-22 13:53:20.620922
# Get all files in /Volumes/grad/surfrad/products_level1/radiation_netcdf/v1.1/tbl with "files_between" function and start: 2025-09-27 13:53:20.620948, end: 2026-09-22 13:53:20.620959 and file_name_format: *{date:%Y%m%d}*
#                                                        p2f_in
# datetime
# 2026-09-21  /Volumes/grad/surfrad/products_level1/radiatio...

# %%
self.process(raise_errors=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  356
# New values
# normalized_total_shortwave_power_exponent: 1.2850282,
# normalized_total_shortwave_lower_limit_low_sun: 1045.82,
# normalized_total_shortwave_lower_limit_high_sun: 1045.8,
# normalized_total_shortwave_upper_limit: 1345.82,
# normalized_diffuse_ratio_power_exponent: -0.8563788
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  354
# New values
# normalized_total_shortwave_power_exponent: 1.2831302,
# normalized_total_shortwave_lower_limit_low_sun: 1044.64,
# normalized_total_shortwave_lower_limit_high_sun: 1044.6,
# normalized_total_shortwave_upper_limit: 1344.64,
# normalized_diffuse_ratio_power_exponent: -0.8584314
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  353
# New values
# normalized_total_shortwave_power_exponent: 1.2825817,
# normalized_total_shortwave_lower_limit_low_sun: 1044.32,
# normalized_total_shortwave_lower_limit_high_sun: 1044.3,
# normalized_total_shortwave_upper_limit: 1344.32,
# normalized_diffuse_ratio_power_exponent: -0.8590474
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  353
# New values
# normalized_total_shortwave_power_exponent: 1.2511964,
# normalized_total_shortwave_lower_limit_low_sun: 1075.51,
# normalized_total_shortwave_lower_limit_high_sun: 1075.5,
# normalized_total_shortwave_upper_limit: 1275.51,
# normalized_diffuse_ratio_power_exponent: -0.8385078
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07785715500502276
# overwriting normalized_diffuse_ratio_power_exponent with -0.8385078017417803. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1175.5148659909576
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2511963911249255. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.251,
# normalized_total_shortwave_lower_limit_low_sun: 1075.5,
# normalized_total_shortwave_lower_limit_high_sun: 1075.5,
# normalized_total_shortwave_upper_limit: 1275.5,
# normalized_diffuse_ratio_power_exponent: -0.839
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  37
# Not enough clear sky points (37 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07785715500502276
# overwriting normalized_diffuse_ratio_power_exponent with -0.8385078017417803. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1175.5148659909576
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2511963911249255. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.251,
# normalized_total_shortwave_lower_limit_low_sun: 1075.5,
# normalized_total_shortwave_lower_limit_high_sun: 1075.5,
# normalized_total_shortwave_upper_limit: 1275.5,
# normalized_diffuse_ratio_power_exponent: -0.839
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  42
# Not enough clear sky points (42 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07785715500502276
# overwriting normalized_diffuse_ratio_power_exponent with -0.8385078017417803. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1175.5148659909576
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2511963911249255. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.251,
# normalized_total_shortwave_lower_limit_low_sun: 1075.5,
# normalized_total_shortwave_lower_limit_high_sun: 1075.5,
# normalized_total_shortwave_upper_limit: 1275.5,
# normalized_diffuse_ratio_power_exponent: -0.839
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  216
# New values
# normalized_total_shortwave_power_exponent: 1.2861479,
# normalized_total_shortwave_lower_limit_low_sun: 1082.48,
# normalized_total_shortwave_lower_limit_high_sun: 1082.5,
# normalized_total_shortwave_upper_limit: 1382.48,
# normalized_diffuse_ratio_power_exponent: -0.8395794
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  216
# New values
# normalized_total_shortwave_power_exponent: 1.2861479,
# normalized_total_shortwave_lower_limit_low_sun: 1082.48,
# normalized_total_shortwave_lower_limit_high_sun: 1082.5,
# normalized_total_shortwave_upper_limit: 1382.48,
# normalized_diffuse_ratio_power_exponent: -0.8395794
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  216
# New values
# normalized_total_shortwave_power_exponent: 1.2861479,
# normalized_total_shortwave_lower_limit_low_sun: 1082.48,
# normalized_total_shortwave_lower_limit_high_sun: 1082.5,
# normalized_total_shortwave_upper_limit: 1382.48,
# normalized_diffuse_ratio_power_exponent: -0.8395794
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  216
# New values
# normalized_total_shortwave_power_exponent: 1.2750439,
# normalized_total_shortwave_lower_limit_low_sun: 1119.92,
# normalized_total_shortwave_lower_limit_high_sun: 1119.9,
# normalized_total_shortwave_upper_limit: 1319.92,
# normalized_diffuse_ratio_power_exponent: -0.8226114
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.0589642781315215
# overwriting normalized_diffuse_ratio_power_exponent with -0.82261142101759. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1219.9248621044367
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2750438855121218. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.275,
# normalized_total_shortwave_lower_limit_low_sun: 1119.9,
# normalized_total_shortwave_lower_limit_high_sun: 1119.9,
# normalized_total_shortwave_upper_limit: 1319.9,
# normalized_diffuse_ratio_power_exponent: -0.823
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  49
# Not enough clear sky points (49 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.0589642781315215
# overwriting normalized_diffuse_ratio_power_exponent with -0.82261142101759. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1219.9248621044367
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2750438855121218. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.275,
# normalized_total_shortwave_lower_limit_low_sun: 1119.9,
# normalized_total_shortwave_lower_limit_high_sun: 1119.9,
# normalized_total_shortwave_upper_limit: 1319.9,
# normalized_diffuse_ratio_power_exponent: -0.823
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  615
# New values
# normalized_total_shortwave_power_exponent: 1.2684604,
# normalized_total_shortwave_lower_limit_low_sun: 1051.37,
# normalized_total_shortwave_lower_limit_high_sun: 1051.4,
# normalized_total_shortwave_upper_limit: 1351.37,
# normalized_diffuse_ratio_power_exponent: -0.8550522
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  612
# New values
# normalized_total_shortwave_power_exponent: 1.2680367,
# normalized_total_shortwave_lower_limit_low_sun: 1051.04,
# normalized_total_shortwave_lower_limit_high_sun: 1051.0,
# normalized_total_shortwave_upper_limit: 1351.04,
# normalized_diffuse_ratio_power_exponent: -0.8568373
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  612
# New values
# normalized_total_shortwave_power_exponent: 1.2680367,
# normalized_total_shortwave_lower_limit_low_sun: 1051.04,
# normalized_total_shortwave_lower_limit_high_sun: 1051.0,
# normalized_total_shortwave_upper_limit: 1351.04,
# normalized_diffuse_ratio_power_exponent: -0.8568373
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  612
# New values
# normalized_total_shortwave_power_exponent: 1.2561460,
# normalized_total_shortwave_lower_limit_low_sun: 1091.63,
# normalized_total_shortwave_lower_limit_high_sun: 1091.6,
# normalized_total_shortwave_upper_limit: 1291.63,
# normalized_diffuse_ratio_power_exponent: -0.8357757
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.06599778040701329
# overwriting normalized_diffuse_ratio_power_exponent with -0.8357757372839919. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1191.626510031913
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2561459843263572. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.256,
# normalized_total_shortwave_lower_limit_low_sun: 1091.6,
# normalized_total_shortwave_lower_limit_high_sun: 1091.6,
# normalized_total_shortwave_upper_limit: 1291.6,
# normalized_diffuse_ratio_power_exponent: -0.836
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  505
# New values
# normalized_total_shortwave_power_exponent: 1.2538624,
# normalized_total_shortwave_lower_limit_low_sun: 1051.18,
# normalized_total_shortwave_lower_limit_high_sun: 1051.2,
# normalized_total_shortwave_upper_limit: 1351.18,
# normalized_diffuse_ratio_power_exponent: -0.7980023
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  505
# New values
# normalized_total_shortwave_power_exponent: 1.2543997,
# normalized_total_shortwave_lower_limit_low_sun: 1051.67,
# normalized_total_shortwave_lower_limit_high_sun: 1051.7,
# normalized_total_shortwave_upper_limit: 1351.67,
# normalized_diffuse_ratio_power_exponent: -0.7932111
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  505
# New values
# normalized_total_shortwave_power_exponent: 1.2543997,
# normalized_total_shortwave_lower_limit_low_sun: 1051.67,
# normalized_total_shortwave_lower_limit_high_sun: 1051.7,
# normalized_total_shortwave_upper_limit: 1351.67,
# normalized_diffuse_ratio_power_exponent: -0.7932111
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  505
# New values
# normalized_total_shortwave_power_exponent: 1.2443585,
# normalized_total_shortwave_lower_limit_low_sun: 1094.42,
# normalized_total_shortwave_lower_limit_high_sun: 1094.4,
# normalized_total_shortwave_upper_limit: 1294.42,
# normalized_diffuse_ratio_power_exponent: -0.7768704
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.06291350955127198
# overwriting normalized_diffuse_ratio_power_exponent with -0.7768703657445991. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1194.4236657838255
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2443585092124616. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.244,
# normalized_total_shortwave_lower_limit_low_sun: 1094.4,
# normalized_total_shortwave_lower_limit_high_sun: 1094.4,
# normalized_total_shortwave_upper_limit: 1294.4,
# normalized_diffuse_ratio_power_exponent: -0.777
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.06291350955127198
# overwriting normalized_diffuse_ratio_power_exponent with -0.7768703657445991. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1194.4236657838255
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.2443585092124616. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.244,
# normalized_total_shortwave_lower_limit_low_sun: 1094.4,
# normalized_total_shortwave_lower_limit_high_sun: 1094.4,
# normalized_total_shortwave_upper_limit: 1294.4,
# normalized_diffuse_ratio_power_exponent: -0.777
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  138
# New values
# normalized_total_shortwave_power_exponent: 1.3010734,
# normalized_total_shortwave_lower_limit_low_sun: 1133.41,
# normalized_total_shortwave_lower_limit_high_sun: 1133.4,
# normalized_total_shortwave_upper_limit: 1433.41,
# normalized_diffuse_ratio_power_exponent: -0.8350541
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  137
# New values
# normalized_total_shortwave_power_exponent: 1.3010956,
# normalized_total_shortwave_lower_limit_low_sun: 1133.44,
# normalized_total_shortwave_lower_limit_high_sun: 1133.4,
# normalized_total_shortwave_upper_limit: 1433.44,
# normalized_diffuse_ratio_power_exponent: -0.8357378
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  137
# New values
# normalized_total_shortwave_power_exponent: 1.3010956,
# normalized_total_shortwave_lower_limit_low_sun: 1133.44,
# normalized_total_shortwave_lower_limit_high_sun: 1133.4,
# normalized_total_shortwave_upper_limit: 1433.44,
# normalized_diffuse_ratio_power_exponent: -0.8357378
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  137
# New values
# normalized_total_shortwave_power_exponent: 1.2996735,
# normalized_total_shortwave_lower_limit_low_sun: 1181.55,
# normalized_total_shortwave_lower_limit_high_sun: 1181.5,
# normalized_total_shortwave_upper_limit: 1381.55,
# normalized_diffuse_ratio_power_exponent: -0.8319377
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# ...
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07894372956231478
# overwriting normalized_diffuse_ratio_power_exponent with -0.7808919680495429. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1090.1382982666062
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.0809147068101277. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.081,
# normalized_total_shortwave_lower_limit_low_sun: 990.1,
# normalized_total_shortwave_lower_limit_high_sun: 990.1,
# normalized_total_shortwave_upper_limit: 1190.1,
# normalized_diffuse_ratio_power_exponent: -0.781
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  4
# Not enough clear sky points (4 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07894372956231478
# overwriting normalized_diffuse_ratio_power_exponent with -0.7808919680495429. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1090.1382982666062
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.0809147068101277. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.081,
# normalized_total_shortwave_lower_limit_low_sun: 990.1,
# normalized_total_shortwave_lower_limit_high_sun: 990.1,
# normalized_total_shortwave_upper_limit: 1190.1,
# normalized_diffuse_ratio_power_exponent: -0.781
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07894372956231478
# overwriting normalized_diffuse_ratio_power_exponent with -0.7808919680495429. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1090.1382982666062
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.0809147068101277. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.081,
# normalized_total_shortwave_lower_limit_low_sun: 990.1,
# normalized_total_shortwave_lower_limit_high_sun: 990.1,
# normalized_total_shortwave_upper_limit: 1190.1,
# normalized_diffuse_ratio_power_exponent: -0.781
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  0
# Not enough clear sky points (0 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07894372956231478
# overwriting normalized_diffuse_ratio_power_exponent with -0.7808919680495429. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1090.1382982666062
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.0809147068101277. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.081,
# normalized_total_shortwave_lower_limit_low_sun: 990.1,
# normalized_total_shortwave_lower_limit_high_sun: 990.1,
# normalized_total_shortwave_upper_limit: 1190.1,
# normalized_diffuse_ratio_power_exponent: -0.781
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  4
# Not enough clear sky points (4 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0008
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable normalized_diffuse_ratio_power_coefficient to 0.07894372956231478
# overwriting normalized_diffuse_ratio_power_exponent with -0.7808919680495429. (old value: -0.8)
# setting new variable normalized_total_shortwave_power_coefficient to 1090.1382982666062
# As normalized_total_shortwave_power_coefficient was set the limites have been updated.
# overwriting normalized_total_shortwave_power_exponent with 1.0809147068101277. (old value: 1.18)
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.081,
# normalized_total_shortwave_lower_limit_low_sun: 990.1,
# normalized_total_shortwave_lower_limit_high_sun: 990.1,
# normalized_total_shortwave_upper_limit: 1190.1,
# normalized_diffuse_ratio_power_exponent: -0.781
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  47
# Not enough clear sky points (47 < 99) -> skip optimazation, keep old params
# Optimization canceled as not enough clear sky points observed.
# .We have to wait for the next day to to finish this local day.
# .

# %% [markdown]
# ## For testing

# %%
# i = 0
i += 1
out = self.process_row(iloc = i, 
                         save = False, 
                         # test = True,
                        )

ds = out['ds_wholeday']

# ds.global_horizontal.plot()

bbi = out['bbi']

bbi.plot_overview(show_clearsky=True)
# Out:
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# setting new variable maximum_solar_zenith_angle to 90.0
# setting new variable maximum_diffuse_shortwave_irradiance to 150.0
# setting new variable maximum_diffuse_shortwave_cosine_exponent to 0.5
# setting new variable normalized_diffuse_ratio_standard_deviation_limit to 0.0012
# Casting normalized diffuse ratio standard deviation window to int
# setting new variable normalized_diffuse_ratio_standard_deviation_window_minutes to 11
# setting new variable shortwave_temporal_gradient_envelope_constant to 2.0
# setting new variable minimum_total_shortwave_irradiance to 1.0
# setting new variable normalized_total_shortwave_intermediate_iteration_half_width to 150.0
# setting new variable normalized_total_shortwave_final_iteration_half_width to 100.0
# setting new variable normalized_total_shortwave_low_sun_cosine_boundary to 0.2
# setting new variable minimum_clear_sky_duration_for_daily_fit to 110
# setting new variable diffuse_ratio_exponent_lower_validity_limit to -0.95
# setting new variable diffuse_ratio_exponent_upper_validity_limit to -0.4
# setting new variable normalized_total_shortwave_power_exponent to 1.18
# setting new variable normalized_diffuse_ratio_power_exponent to -0.8
# setting new variable normalized_total_shortwave_lower_limit_low_sun to 900.0
# setting new variable normalized_total_shortwave_lower_limit_high_sun to 1000.0
# setting new variable normalized_total_shortwave_upper_limit to 1250.0
# Warning: mask_normalized_global_magnitude not found in dataset. Skipping.
# Warning: mask_normalized_diffuse_ratio_variability not found in dataset. Skipping.
# Warning: mask_clear_sky_shortwave not found in dataset. Skipping.
# Warning: mask_diffuse_magnitude not found in dataset. Skipping.
# Warning: mask_global_irradiance_temporal_gradient not found in dataset. Skipping.
# Warning: clearsky_global_horizontal not found in dataset. Skipping.
# Warning: clearsky_diffuse_horizontal not found in dataset. Skipping.
# ################
# Original values
# normalized_total_shortwave_power_exponent: 1.180,
# normalized_total_shortwave_lower_limit_low_sun: 900.0,
# normalized_total_shortwave_lower_limit_high_sun: 1000.0,
# normalized_total_shortwave_upper_limit: 1250.0,
# normalized_diffuse_ratio_power_exponent: -0.800
# ################
# Iteration 1/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  244
# New values
# normalized_total_shortwave_power_exponent: 1.2479359,
# normalized_total_shortwave_lower_limit_low_sun: 1024.23,
# normalized_total_shortwave_lower_limit_high_sun: 1024.2,
# normalized_total_shortwave_upper_limit: 1324.23,
# normalized_diffuse_ratio_power_exponent: -0.7559991
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 2/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 3/4
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2501459,
# normalized_total_shortwave_lower_limit_low_sun: 1025.91,
# normalized_total_shortwave_lower_limit_high_sun: 1025.9,
# normalized_total_shortwave_upper_limit: 1325.91,
# normalized_diffuse_ratio_power_exponent: -0.7570847
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ################
# Iteration 4/4
# Set weight_by_mu0 = True for last iteration
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# Number of clearsky (valid) points:  247
# New values
# normalized_total_shortwave_power_exponent: 1.2182799,
# normalized_total_shortwave_lower_limit_low_sun: 1052.32,
# normalized_total_shortwave_lower_limit_high_sun: 1052.3,
# normalized_total_shortwave_upper_limit: 1252.32,
# normalized_diffuse_ratio_power_exponent: -0.7793289
# Reset mask_normalized_global_magnitude in dataset.
# Reset mask_normalized_diffuse_ratio_variability in dataset.
# Reset mask_clear_sky_shortwave in dataset.
# Reset mask_diffuse_magnitude in dataset.
# Reset mask_global_irradiance_temporal_gradient in dataset.
# ### mu0 coverage test results
# normalized_total_shortwave_cosine_coverage_sufficient: True, Keep total-SW a,b.,
# normalized_total_shortwave_final_iteration_cosine_coverage_sufficient: False, Discard total-SW a,b; interpolate them.,
# diffuse_ratio_cosine_coverage_sufficient: True,
# diffuse_ratio_power_exponent_below_validity_limit: False, pass.,
# diffuse_ratio_power_exponent_above_validity_limit: False, pass.,
#
# Running clear sky tests (RADFLUX equivalent)
# Running normalized global magnitude test
# Running diffuse magnitude test
# Running global irradiance temporal gradient test
# Running normalized diffuse ratio variability test
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='datetime', ylabel='Clear sky diffuse horizontal\nirradiance (empirical power\nlaw fit) [W m-2]'>)

# %% [markdown]
# # parameter check

# %%
import atmPy.radiation.radflux.radflux_db as atmrfdb

# %%
db12 = atmrfdb.RadfluxParameterDatabase('radflux_params_tbl_12.db')
db = db12
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df12 = df

# %%
db10 = atmrfdb.RadfluxParameterDatabase('radflux_params_tbl_10.db')
db = db10
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df10 = df

# %%
db08 = atmrfdb.RadfluxParameterDatabase('radflux_params_tbl_08.db')
db = db08
df = db.dump_radflux_parameters()
df.index = df.apply(lambda row: pd.to_datetime(row.name), axis =1 )
df08 = df

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['12','10','08'
       # '20', '19', '18', '17', '15'
      ]
dfs = [df12, df10, df08
       # df20, df19, df18, df17, df15
      ]
for i, df in enumerate(dfs):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
df = df12
nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()

ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()

f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 2)

sers = [nts_a, nts_b,ndr_a,ndr_b]

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]
for e,a in enumerate(aa):
    sers[e].plot(ax = a, ls = '', marker = '.')
    a.text(posn[0], posn[1], names[e], transform = a.transAxes)
    a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    # '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    # df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= [#'25',
    '20', 
       '19',
    '18', 
    # '17', '15'
]
for i, df in enumerate([#df25, 
    df20, 
    df19, 
    df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()

# %%
f,aa = plt.subplots(4, sharex= True, gridspec_kw={'hspace':0})
f.set_figheight(f.get_figheight() * 3)
f.set_figwidth(f.get_figwidth() *1.5)

posn = (0.05, 0.9)
possum = (0.8, 0.9)
names = ['normalized_total_shortwave_power_coefficient',
         'normalized_total_shortwave_power_exponent',
         'normalized_diffuse_ratio_power_coefficient',
         'normalized_diffuse_ratio_power_exponent'
        ]

labs= ['25',
    '20', 
       # '19',
    # '18', 
    # '17', '15'
]
for i, df in enumerate([
    df25, 
    df20, 
    # df19, 
    # df18, 
    # df17, df15
]):
    nts_a = df.normalized_total_shortwave_power_coefficient.where(df.normalized_total_shortwave_power_coefficient_is_valid == 1).dropna()
    nts_b = df.normalized_total_shortwave_power_exponent.where(df.normalized_total_shortwave_power_exponent_is_valid == 1).dropna()
    
    ndr_a = df.normalized_diffuse_ratio_power_coefficient.where(df.normalized_diffuse_ratio_power_coefficient_is_valid == 1).dropna()
    ndr_b = df.normalized_diffuse_ratio_power_exponent.where(df.normalized_diffuse_ratio_power_exponent_is_valid == 1).dropna()
    sers = [nts_a, nts_b,ndr_a,ndr_b]
    
    
    for e,a in enumerate(aa):
        sers[e].plot(ax = a, ls = '', marker = '.', label = f'ndr_lim: 0.00{labs[i]}')
        a.text(posn[0], posn[1], names[e], transform = a.transAxes)
        # a.text(possum[0], possum[1], sers[e].shape[0], transform = a.transAxes)

a = aa[0]
a.legend()
