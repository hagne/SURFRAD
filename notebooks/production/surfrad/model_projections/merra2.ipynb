# %%
import surfradpy.scripts.surfrad_merra2 as srfmerra

# %%
reload(srfmerra)
# Out:
# <module 'surfradpy.scripts.surfrad_merra2' from '/Users/htelg/prog/SURFRAD/surfradpy/scripts/surfrad_merra2.py'>

# %%
out = srfmerra.run(prefix='/Volumes',
                   # test = 1, 
                   log_folder=None,
                  raise_errors=True,)
# Out:
# start time: 2026-08-13 12:53:55.150067
# start surfrad_merra2
# workplan.shape: (43, 1)
# Granules not found for 2026-07-02. Stopping processing.
# number of cleanes: 0
# number of errors: 0
# number of warnings: 0
# time finished: 2026-08-13 12:54:02.277007
# total processing time: 0.0019797055555555556 hours
# No log file specified, skipping logging.

# %%
pi = out['product_instance']

pi.workplan
# Out:
#                                                       p2f_out
# 2026-07-02  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-03  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-04  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-05  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-06  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-07  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-08  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-09  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-10  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-11  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-12  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-13  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-14  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-15  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-16  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-17  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-18  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-19  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-20  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-21  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-22  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-23  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-24  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-25  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-26  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-27  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-28  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-29  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-30  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-07-31  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-01  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-02  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-03  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-04  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-05  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-06  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-07  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-08  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-09  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-10  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-11  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-12  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...
# 2026-08-13  /Volumes/stu3data2/Model_data/merra_2/M2T1NXSL...

# %%
try: 
    out = srfmerra.run(prefix='/Volumes',
                   # test = 1, 
                   log_folder=None,
                  raise_errors=True,)
except Exception as e:
    bla = e

# %%
(bla.args[0] == 'Bad Request') and (bla.args[1] == 'Error: No matching granules found.')
# Out:
# True

# %%
bla.args[1] == 'Error: No matching granules found.'
# Out:
# 'Error: No matching granules found.'

# %%
bla.with_traceback()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 bla.with_traceback(bla)
#
# TypeError: __traceback__ must be a traceback or None

# %%
# pi.workplan.p2f_out.iloc[0]
# Out:
# PosixPath('/Volumes/stu3data2/Model_data/merra_2/M2T1NXSLV/surfrad/v0.1/2026/surfrad_merra2_M2T1NXSLV_20260525.nc')

# %%
out_pr = pi.process_row(iloc= 0, save = False)
# Out:
#  [ Processing:   0% ] |                                                   | [/]
#  [ Processing:   0% ] |                                                   | [-]
#  [ Processing:   0% ] |                                                   | [\]
#  [ Processing:   0% ] |                                                   | [|]
#  [ Processing:   0% ] |                                                   | [/]
#  [ Processing:   0% ] |                                                   | [-]
#  [ Processing:   0% ] |                                                   | [\]
#  [ Processing:   0% ] |                                                   | [|]
#  [ Processing:   0% ] |                                                   | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing:   9% ] |####                                               | [-]
#  [ Processing:   9% ] |####                                               | [\]
#  [ Processing:   9% ] |####                                               | [|]
#  [ Processing:   9% ] |####                                               | [/]
#  [ Processing: 100% ] |###################################################| [-]
#  [ Processing: 100% ] |###################################################| [|]
# /Users/htelg/.cache/atmPy/merra2/M2T1NXSLV/harmony/59a72ac74cac/264788824_M2T1NXSLV.5.12.4_MERRA2_400.tavg1_2d_slv_Nx.20260525_subsetted.nc4

# %%
out_pr['dsout'].sel(site = 'tbl').TO3.plot()

# %% [markdown]
# # Test

# %%
ds = xr.open_dataset('/Volumes/stu3data2/Model_data/merra_2/M2T1NXSLV/surfrad/v0.1/2026/surfrad_merra2_M2T1NXSLV_20260531.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 73kB
# Dimensions:    (datetime: 24, site: 8)
# Coordinates:
#   * datetime   (datetime) datetime64[ns] 192B 2026-05-31T00:30:00 ... 2026-05...
#   * site       (site) <U3 96B 'inl' 'bnd' 'dra' 'gwn' 'psu' 'sxf' 'tbl' 'fpe'
#     lat        (site) float64 64B ...
#     lon        (site) float64 64B ...
#     site_id    (site) int64 64B ...
#     site_name  (site) <U17 544B ...
#     elevation  (site) float64 64B ...
# Data variables: (12/47)
#     CLDPRS     (datetime, site) float64 2kB ...
#     CLDTMP     (datetime, site) float64 2kB ...
#     DISPH      (datetime, site) float64 2kB ...
#     H1000      (datetime, site) float64 2kB ...
#     H250       (datetime, site) float64 2kB ...
#     H500       (datetime, site) float64 2kB ...
#     ...         ...
#     V250       (datetime, site) float64 2kB ...
#     V2M        (datetime, site) float64 2kB ...
#     V500       (datetime, site) float64 2kB ...
#     V50M       (datetime, site) float64 2kB ...
#     V850       (datetime, site) float64 2kB ...
#     ZLCL       (datetime, site) float64 2kB ...
# Attributes: (12/52)
#     DODS_EXTRA.Unlimited_Dimension:    time
#     History:                           Original file generated: Wed Jun 10 20...
#     Comment:                           GMAO filename: d5124_m2_jan10.tavg1_2d...
#     Filename:                          MERRA2_400.tavg1_2d_slv_Nx.20260531.nc4
#     Conventions:                       CF-1
#     Institution:                       NASA Global Modeling and Assimilation ...
#     ...                                ...
#     product_version:                   0.1
#     interpolation_method:              linear latitude-longitude
#     spatial_subset_bbox:               -116.25, 34.0, -77.5, 48.5
#     spatial_subset_bbox_order:         west, south, east, north
#     site_count:                        8
#     parent_files:                      /Users/htelg/.cache/atmPy/merra2/M2T1N...
