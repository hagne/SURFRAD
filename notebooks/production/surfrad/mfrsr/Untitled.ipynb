# %%
import surfradpy.scripts as srfscript

# %%
srfscript.surfrad_mfrsr_full_process.run(prefix='/Volumes/grad')
# Out:
# start time: 2026-02-02 12:09:50.352249
# bnd
# opening file /Volumes/grad/Inst/MFR/SURFRAD/bnd/mfrsr/raw/2025/bnd_mfrsr_20251204_020002.xmd ... done
# 1
# Last file was incomplete
# bnd workplan.shape: (11, 2)
# ....dra
# opening file /Volumes/grad/Inst/MFR/SURFRAD/dra/mfrsr/raw/2025/dra_mfrsr_20251204_000116.xmd ... done
# 1
# Last file was incomplete
# dra workplan.shape: (11, 2)
# ....gwn
# opening file /Volumes/grad/Inst/MFR/SURFRAD/gwn/mfrsr/raw/2025/gwn_mfrsr_20251204_020409.xmd ... done
# 1
# Last file was incomplete
# gwn workplan.shape: (11, 2)
# ....psu
# opening file /Volumes/grad/Inst/MFR/SURFRAD/psu/mfrsr/raw/2025/psu_mfrsr_20251204_030534.xmd ... done
# 1
# Last file was incomplete
# psu workplan.shape: (11, 2)
# ....sxf
# opening file /Volumes/grad/Inst/MFR/SURFRAD/sxf/mfrsr/raw/2025/sxf_mfrsr_20251204_020655.xmd ... done
# 1
# Last file was incomplete
# sxf workplan.shape: (11, 2)
# ....
