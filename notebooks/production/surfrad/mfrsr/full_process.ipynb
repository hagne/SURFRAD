# %%
import surfradpy.scripts as srfscript

# %%
srfscript.surfrad_mfrsr_full_process.run(prefix='/Volumes/grad', verbose = True)
# Out:
# Running MFRSR full process with prefix=/Volumes/grad
# start time: 2026-02-02 16:14:22.345293
# bnd
# Get all files in /Volumes/grad/Inst/MFR/SURFRAD/bnd/mfrsr/raw with "files_between" function and start: 2025-12-04 16:14:22.345319, end: 2026-02-02 16:14:22.345319 and glob pattern: *.xmd
# opening file /Volumes/grad/Inst/MFR/SURFRAD/bnd/mfrsr/raw/2025/bnd_mfrsr_20251204_020002.xmd ... done
# 1
# Check if new files (last: /Volumes/grad/Inst/MFR/SURFRAD/bnd/mfrsr/raw/2026/bnd_mfrsr_20260202_130109.xmd) are new and if it should be added to last file. The last raw files that can be found in the last processed file is /Volumes/grad/Inst/MFR/SURFRAD/bnd/mfrsr/raw/2026/bnd_mfrsr_20260202_130109.xmd
# No new raw files to process, workplan is empty
# bnd workplan.shape: (0, 2)
# Workplan is empty, nothing to do
# dra
# ...
